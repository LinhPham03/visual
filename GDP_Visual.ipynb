# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('D:\\raw\\GDPlist.csv',encoding= 'unicode_escape')
df
# Out:
#          Country      Continent  GDP (millions of US$)
# 0    Afghanistan           Asia                  18181
# 1        Albania         Europe                  12847
# 2        Algeria         Africa                 190709
# 3         Angola         Africa                 100948
# 4      Argentina  South America                 447644
# ..           ...            ...                    ...
# 120   Uzbekistan           Asia                  45353
# 121    Venezuela  South America                 315841
# 122      Vietnam           Asia                 122722
# 123        Yemen         Africa                  33675
# 124       Zambia         Africa                  19206
#
# [125 rows x 3 columns]

# %%
data = df[df['Continent'] == 'South America']
data
# Out:
#        Country      Continent  GDP (millions of US$)
# 4    Argentina  South America                 447644
# 15      Brazil  South America                2492908
# 22       Chile  South America                 248411
# 24    Colombia  South America                 328422
# 34     Ecuador  South America                  66381
# 86    Paraguay  South America                  21236
# 87        Peru  South America                 173502
# 119    Uruguay  South America                  46872
# 121  Venezuela  South America                 315841

# %%
plt.bar(df['Country'],df['GDP (millions of US$)'])

plt.title('GDP các nước ở South America', fontsize =14)
plt.xlabel('Nước', fontsize = 12)
plt.ylabel('GDP', fontsize = 12)

fig = plt.gcf()
fig.set_size_inches(120,50)
plt.show()

# %%
df
# Out:
#          Country      Continent  GDP (millions of US$)
# 0    Afghanistan           Asia                  18181
# 1        Albania         Europe                  12847
# 2        Algeria         Africa                 190709
# 3         Angola         Africa                 100948
# 4      Argentina  South America                 447644
# ..           ...            ...                    ...
# 120   Uzbekistan           Asia                  45353
# 121    Venezuela  South America                 315841
# 122      Vietnam           Asia                 122722
# 123        Yemen         Africa                  33675
# 124       Zambia         Africa                  19206
#
# [125 rows x 3 columns]

# %%
data = df.groupby('Country')['GDP (millions of US$)'].sum()
data
# Out:
# Country
# Afghanistan     18181
# Albania         12847
# Algeria        190709
# Angola         100948
# Argentina      447644
#                 ...
# Uzbekistan      45353
# Venezuela      315841
# Vietnam        122722
# Yemen           33675
# Zambia          19206
# Name: GDP (millions of US$), Length: 125, dtype: int64

# %%
statis = []

nation = ['Vietnam', 'Indonesia','Cambodia', 'Thailand', 'Malaysia']
for i in nation:
    statis.append(data[i])

statis
# Out:
# [122722, 845680, 12861, 345649, 278680]

# %%
plt.pie(statis, labels = nation, autopct = '%1.2f%%')
plt.title('Sản lượng xuất khẩu năm 2021', fontsize = 14)

plt.show()
